# %%
import pandas as pd
import numpy as np
import random
import warnings
warnings.filterwarnings('ignore')

# %%
def randomNumber(x,y):
    return random.randint(x,y)
def randomDate(x):
    return random.randint(5,x)
def randomYear(x):
    return random.randint(1,x)
def randomColor():
    r = lambda: random.randint(0,255)
    return ('#%02X%02X%02X' % (r(),r(),r()))
def randomDateCust():
    return random.randint(1,2)

# %%
# for ground owners
#(date-pk,year(not required),day, month, week number , groundName, timeslot chosen , sport chosen ) --> cost spent

years = ['2012','2013','2014','2015','2016','2017','2018','2019','2020','2021']

days = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

groundNames = ['Ground1','Ground2','Ground3','Ground4']

months = ['January','February','March','April','May','June','July','August','September','October','November','December']

winter_months = ['October','November','December','January']

spring_months = ['February','March']

summer_months = ['April','May','June','July']

monsoon_months = ['August','September']

sports = ['sport1','sport2','sport3','sport4','sport5','sport6']

#for ground 1 : 
g1_prices = {'sport1':65,'sport2':72,'sport3':77,'sport4':69,'sport5':86,'sport6':80}


data = [] 
data2=[]
for i in range(1,3000):  
    for i in
    tMonth = ""
    tMonth = months[randomNumber(0,len(months)-1)]
    
    if tMonth in winter_months:
        tot_cust =  randomNumber(7,15)
    
    elif tMonth in spring_months:
        tot_cust =  randomNumber(15,20)
        
    elif tMonth in summer_months:
        tot_cust =  randomNumber(20,30)
            
    elif tMonth in monsoon_months:
        tot_cust =  randomNumber(0,7)
    
    tot_cost=0
    tYear =""
    tDay=""
    tGroundName=""
    tTimeSlot=""
    tSport=""
    tDate = i
    day_cost = []
    
    for j in range(1,tot_cust):    
        tDay = days[randomNumber(0,len(days)-1)]
        tGroundName = groundNames[randomNumber(0,len(groundNames)-1)]
        tTimeSlot = timeslots[randomNumber(0,len(timeslots)-1)]
        tSport = sports[randomNumber(0,len(sports)-1)]
        
        
        tCost = g1_prices[tSport]
        day_cost.append(tCost)
        tot_cost+=tCost
        
        
        if(i<2500):
            tYear = years[0]
        elif(i>=2500 and i<5000):
            tYear = years[1]
        elif(i>=5000 and i<7500):
            tYear = years[2]
        elif(i>=7500 and i<10000):
            tYear = years[3]
        elif(i>=10000 and i<12500):
            tYear = years[4]
        elif(i>=12500 and i<15000):
            tYear = years[5]
        elif(i>=15000 and i<17500):
            tYear = years[6]
        elif(i>=17500 and i<20000):
            tYear = years[7]
        elif(i>=20000 and i<22500):
            tYear = years[8]
        elif(i>=22500 and i<25000):
            tYear = years[9]
        elif(i>=25000 and i<27500):
            tYear = years[10]
        elif(i>=27500 and i<30000):
            tYear = years[11]
        
    data.append([tDate,tYear,tDay,tMonth,tGroundName,tot_cost,tot_cust])


groundOwners_df = pd.DataFrame(data, columns = ['Date','Year', 'Day','Month','GroundName','Cost','TotalCustomers'])

# %%
groundOwners_df.to_csv('regression_dataset.csv', index = False, encoding='utf-8')
